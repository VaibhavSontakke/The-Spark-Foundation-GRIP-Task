# %% [markdown]
# # Task 08-Timeline Analysis : Covid-19
#
# In this task Create a storyboard showing spread of Covid-19 cases in your country or any region
#
# ● Identify interesting patterns and possible reasons helping Covid-19 spread with basic as well as advanced charts
#
# ### Author - Vaibhav Sontakke

# %% [markdown]
# ***Importing Requires libraries***

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
import pylab as pl
# %matplotlib inline
sns.set()

# %% [markdown]
# ****Loading dataset****

# %%
df = pd.read_csv('owid-covid-data.csv')

# %%
#print first five row
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        NaN
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0        1803.987              NaN                597.029
# 1        1803.987              NaN                597.029
# 2        1803.987              NaN                597.029
# 3        1803.987              NaN                597.029
# 4        1803.987              NaN                597.029
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                 9.59             NaN           NaN                  37.746
# 1                 9.59             NaN           NaN                  37.746
# 2                 9.59             NaN           NaN                  37.746
# 3                 9.59             NaN           NaN                  37.746
# 4                 9.59             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                         0.5            64.83                    0.498
# 1                         0.5            64.83                    0.498
# 2                         0.5            64.83                    0.498
# 3                         0.5            64.83                    0.498
# 4                         0.5            64.83                    0.498
#
# [5 rows x 52 columns]

# %%
#print last five row
df.tail()
# Out:
#       iso_code continent  location        date  total_cases  new_cases  \
# 54929      ZWE    Africa  Zimbabwe  2020-12-14      11358.0      112.0
# 54930      ZWE    Africa  Zimbabwe  2020-12-15      11522.0      164.0
# 54931      ZWE    Africa  Zimbabwe  2020-12-16      11749.0      227.0
# 54932      ZWE    Africa  Zimbabwe  2020-12-17      11866.0      117.0
# 54933      ZWE    Africa  Zimbabwe  2020-12-18      12047.0      181.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 54929              74.143         309.0         2.0                2.143  ...
# 54930              87.143         310.0         1.0                1.000  ...
# 54931             106.000         313.0         3.0                1.286  ...
# 54932             112.143         314.0         1.0                1.286  ...
# 54933             126.429         316.0         2.0                1.429  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 54929        1899.775             21.4                307.846
# 54930        1899.775             21.4                307.846
# 54931        1899.775             21.4                307.846
# 54932        1899.775             21.4                307.846
# 54933        1899.775             21.4                307.846
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 54929                 1.82             1.6          30.7
# 54930                 1.82             1.6          30.7
# 54931                 1.82             1.6          30.7
# 54932                 1.82             1.6          30.7
# 54933                 1.82             1.6          30.7
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 54929                  36.791                         1.7            61.49
# 54930                  36.791                         1.7            61.49
# 54931                  36.791                         1.7            61.49
# 54932                  36.791                         1.7            61.49
# 54933                  36.791                         1.7            61.49
#
#        human_development_index
# 54929                    0.535
# 54930                    0.535
# 54931                    0.535
# 54932                    0.535
# 54933                    0.535
#
# [5 rows x 52 columns]

# %%
#print random five row
df.sample(5)
# Out:
#       iso_code continent      location        date  total_cases  new_cases  \
# 46462      LKA      Asia     Sri Lanka  2020-06-08       1857.0       22.0
# 28308      LBR    Africa       Liberia  2020-10-23       1393.0        8.0
# 7657       BFA    Africa  Burkina Faso  2020-06-12        892.0        0.0
# 25372      JOR      Asia        Jordan  2020-06-01        746.0        7.0
# 48060      SYR      Asia         Syria  2020-09-29       4148.0       46.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 46462              30.571          11.0         0.0                0.000  ...
# 28308               2.286          82.0         0.0                0.000  ...
# 7657                0.571          53.0         0.0                0.000  ...
# 25372               5.000           9.0         0.0                0.000  ...
# 48060              38.714         197.0         3.0                2.714  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 46462       11669.077              0.7                197.093
# 28308         752.788             38.6                272.509
# 7657         1703.102             43.7                269.048
# 25372        8337.490              0.1                208.257
# 48060             NaN              NaN                376.264
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 46462                10.68             0.3          27.0
# 28308                 2.42             1.5          18.1
# 7657                  2.42             1.6          23.9
# 25372                11.75             NaN           NaN
# 48060                  NaN             NaN           NaN
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 46462                     NaN                         3.6            76.98
# 28308                   1.188                         0.8            64.10
# 7657                   11.877                         0.4            61.58
# 25372                     NaN                         1.4            74.53
# 48060                  70.598                         1.5            72.70
#
#        human_development_index
# 46462                    0.770
# 28308                    0.435
# 7657                     0.423
# 25372                    0.735
# 48060                    0.536
#
# [5 rows x 52 columns]

# %%
#full summary of the dataframe
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54934 entries, 0 to 54933
# Data columns (total 52 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   iso_code                            54618 non-null  object
#  1   continent                           54285 non-null  object
#  2   location                            54934 non-null  object
#  3   date                                54934 non-null  object
#  4   total_cases                         54379 non-null  float64
#  5   new_cases                           54189 non-null  float64
#  6   new_cases_smoothed                  53233 non-null  float64
#  7   total_deaths                        46307 non-null  float64
#  8   new_deaths                          46133 non-null  float64
#  9   new_deaths_smoothed                 53233 non-null  float64
#  10  total_cases_per_million             54063 non-null  float64
#  11  new_cases_per_million               53874 non-null  float64
#  12  new_cases_smoothed_per_million      52923 non-null  float64
#  13  total_deaths_per_million            46004 non-null  float64
#  14  new_deaths_per_million              45831 non-null  float64
#  15  new_deaths_smoothed_per_million     52923 non-null  float64
#  16  reproduction_rate                   42503 non-null  float64
#  17  icu_patients                        5770 non-null   float64
#  18  icu_patients_per_million            5770 non-null   float64
#  19  hosp_patients                       6471 non-null   float64
#  20  hosp_patients_per_million           6471 non-null   float64
#  21  weekly_icu_admissions               513 non-null    float64
#  22  weekly_icu_admissions_per_million   513 non-null    float64
#  23  weekly_hosp_admissions              793 non-null    float64
#  24  weekly_hosp_admissions_per_million  793 non-null    float64
#  25  new_tests                           25532 non-null  float64
#  26  total_tests                         25471 non-null  float64
#  27  total_tests_per_thousand            25471 non-null  float64
#  28  new_tests_per_thousand              25532 non-null  float64
#  29  new_tests_smoothed                  28527 non-null  float64
#  30  new_tests_smoothed_per_thousand     28527 non-null  float64
#  31  positive_rate                       26609 non-null  float64
#  32  tests_per_case                      26162 non-null  float64
#  33  tests_units                         29607 non-null  object
#  34  total_vaccinations                  17 non-null     float64
#  35  total_vaccinations_per_hundred      17 non-null     float64
#  36  stringency_index                    48571 non-null  float64
#  37  population                          54618 non-null  float64
#  38  population_density                  53462 non-null  float64
#  39  median_age                          52285 non-null  float64
#  40  aged_65_older                       51675 non-null  float64
#  41  aged_70_older                       51988 non-null  float64
#  42  gdp_per_capita                      52284 non-null  float64
#  43  extreme_poverty                     35796 non-null  float64
#  44  cardiovasc_death_rate               52823 non-null  float64
#  45  diabetes_prevalence                 53440 non-null  float64
#  46  female_smokers                      41763 non-null  float64
#  47  male_smokers                        41192 non-null  float64
#  48  handwashing_facilities              26372 non-null  float64
#  49  hospital_beds_per_thousand          48589 non-null  float64
#  50  life_expectancy                     54338 non-null  float64
#  51  human_development_index             52511 non-null  float64
# dtypes: float64(47), object(5)
# memory usage: 21.8+ MB
# None

# %%
#statistical details of the dataset
print(df.describe())
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  5.437900e+04  5.418900e+04        53233.000000  4.630700e+04
# mean   2.425533e+05  2.792888e+03         2765.747005  8.662063e+03
# std    2.354850e+06  2.541319e+04        24432.979813  6.807290e+04
# min    1.000000e+00 -4.607600e+04        -1121.714000  1.000000e+00
# 25%    4.080000e+02  1.000000e+00            4.000000  2.300000e+01
# 50%    4.123000e+03  3.700000e+01           45.286000  1.300000e+02
# 75%    4.053750e+04  4.180000e+02          450.429000  1.127000e+03
# max    7.567281e+07  1.493133e+06       749495.429000  1.674840e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  46133.000000         53233.000000             54063.000000
# mean      72.599701            61.501986              4075.488332
# std      522.982485           466.558705              8286.297936
# min    -1918.000000          -232.143000                 0.001000
# 25%        0.000000             0.000000                83.602000
# 50%        1.000000             0.571000               641.476000
# 75%       10.000000             7.286000              4036.557000
# max    13963.000000         11460.000000             97314.437000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count           53874.000000                    52923.000000
# mean               51.041084                       50.416721
# std               157.742025                      124.533867
# min             -2153.437000                     -276.825000
# 25%                 0.057250                        0.720000
# 50%                 4.194000                        5.492000
# 75%                36.869000                       40.469000
# max              9760.898000                     2648.773000
#
#        total_deaths_per_million  ...  gdp_per_capita  extreme_poverty  \
# count              46004.000000  ...    52284.000000     35796.000000
# mean                 110.749899  ...    19280.633692        13.096804
# std                  210.007653  ...    19702.194546        19.844497
# min                    0.001000  ...      661.240000         0.100000
# 25%                    4.109000  ...     4541.795000         0.500000
# 50%                   20.434000  ...    13111.214000         2.000000
# 75%                  101.926000  ...    27216.445000        18.900000
# max                 1620.602000  ...   116935.600000        77.600000
#
#        cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# count           52823.000000         53440.000000    41763.000000
# mean              255.610902             7.754529       10.599608
# std               117.790581             3.855504       10.433103
# min                79.370000             0.990000        0.100000
# 25%               164.905000             5.290000        1.900000
# 50%               241.219000             7.110000        6.300000
# 75%               325.721000            10.080000       19.300000
# max               724.417000            30.530000       44.000000
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# count  41192.000000            26372.000000                48589.000000
# mean      32.645357               51.226821                    3.046698
# std       13.447760               31.778212                    2.476839
# min        7.700000                1.188000                    0.100000
# 25%       21.600000               20.859000                    1.300000
# 50%       31.400000               50.540000                    2.400000
# 75%       41.100000               83.241000                    4.000000
# max       78.100000               98.999000                   13.800000
#
#        life_expectancy  human_development_index
# count     54338.000000             52511.000000
# mean         73.170261                 0.716472
# std           7.549661                 0.153783
# min          53.280000                 0.354000
# 25%          67.920000                 0.591000
# 50%          74.620000                 0.750000
# 75%          78.730000                 0.843000
# max          86.750000                 0.953000
#
# [8 rows x 47 columns]

# %%
#shape of dataset
print(df.shape)
# Out:
# (54934, 52)

# %%
duplicate_rows_df = df[df.duplicated()]

print("Number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# Number of duplicate rows:  (0, 52)

# %%
#Used to count the number of rows
df.count()
# Out:
# iso_code                              54618
# continent                             54285
# location                              54934
# date                                  54934
# total_cases                           54379
# new_cases                             54189
# new_cases_smoothed                    53233
# total_deaths                          46307
# new_deaths                            46133
# new_deaths_smoothed                   53233
# total_cases_per_million               54063
# new_cases_per_million                 53874
# new_cases_smoothed_per_million        52923
# total_deaths_per_million              46004
# new_deaths_per_million                45831
# new_deaths_smoothed_per_million       52923
# reproduction_rate                     42503
# icu_patients                           5770
# icu_patients_per_million               5770
# hosp_patients                          6471
# hosp_patients_per_million              6471
# weekly_icu_admissions                   513
# weekly_icu_admissions_per_million       513
# weekly_hosp_admissions                  793
# weekly_hosp_admissions_per_million      793
# new_tests                             25532
# total_tests                           25471
# total_tests_per_thousand              25471
# new_tests_per_thousand                25532
# new_tests_smoothed                    28527
# new_tests_smoothed_per_thousand       28527
# positive_rate                         26609
# tests_per_case                        26162
# tests_units                           29607
# total_vaccinations                       17
# total_vaccinations_per_hundred           17
# stringency_index                      48571
# population                            54618
# population_density                    53462
# median_age                            52285
# aged_65_older                         51675
# aged_70_older                         51988
# gdp_per_capita                        52284
# extreme_poverty                       35796
# cardiovasc_death_rate                 52823
# diabetes_prevalence                   53440
# female_smokers                        41763
# male_smokers                          41192
# handwashing_facilities                26372
# hospital_beds_per_thousand            48589
# life_expectancy                       54338
# human_development_index               52511
# dtype: int64

# %%
df.isnull().sum()
# Out:
# iso_code                                316
# continent                               649
# location                                  0
# date                                      0
# total_cases                             555
# new_cases                               745
# new_cases_smoothed                     1701
# total_deaths                           8627
# new_deaths                             8801
# new_deaths_smoothed                    1701
# total_cases_per_million                 871
# new_cases_per_million                  1060
# new_cases_smoothed_per_million         2011
# total_deaths_per_million               8930
# new_deaths_per_million                 9103
# new_deaths_smoothed_per_million        2011
# reproduction_rate                     12431
# icu_patients                          49164
# icu_patients_per_million              49164
# hosp_patients                         48463
# hosp_patients_per_million             48463
# weekly_icu_admissions                 54421
# weekly_icu_admissions_per_million     54421
# weekly_hosp_admissions                54141
# weekly_hosp_admissions_per_million    54141
# new_tests                             29402
# total_tests                           29463
# total_tests_per_thousand              29463
# new_tests_per_thousand                29402
# new_tests_smoothed                    26407
# new_tests_smoothed_per_thousand       26407
# positive_rate                         28325
# tests_per_case                        28772
# tests_units                           25327
# total_vaccinations                    54917
# total_vaccinations_per_hundred        54917
# stringency_index                       6363
# population                              316
# population_density                     1472
# median_age                             2649
# aged_65_older                          3259
# aged_70_older                          2946
# gdp_per_capita                         2650
# extreme_poverty                       19138
# cardiovasc_death_rate                  2111
# diabetes_prevalence                    1494
# female_smokers                        13171
# male_smokers                          13742
# handwashing_facilities                28562
# hospital_beds_per_thousand             6345
# life_expectancy                         596
# human_development_index                2423
# dtype: int64

# %%
df1=df[["date","total_cases","new_cases","total_deaths","new_tests","total_tests"]]
df1.head()
# Out:
#          date  total_cases  new_cases  total_deaths  new_tests  total_tests
# 0  2020-02-24          1.0        NaN           NaN        NaN          NaN
# 1  2020-02-25          1.0        0.0           NaN        NaN          NaN
# 2  2020-02-26          1.0        0.0           NaN        NaN          NaN
# 3  2020-02-27          1.0        0.0           NaN        NaN          NaN
# 4  2020-02-28          1.0        0.0           NaN        NaN          NaN

# %%
df1.mean()
# Out:
# total_cases     2.425533e+05
# new_cases       2.792888e+03
# total_deaths    8.662063e+03
# new_tests       3.102260e+04
# total_tests     2.851521e+06
# dtype: float64

# %%
df1.cov()
# Out:
#                total_cases     new_cases  total_deaths     new_tests  \
# total_cases   5.545319e+12  5.714060e+10  1.690021e+11  9.926945e+10
# new_cases     5.714060e+10  6.458301e+08  1.772318e+09  1.097752e+09
# total_deaths  1.690021e+11  1.772318e+09  4.633920e+09  2.366455e+09
# new_tests     9.926945e+10  1.097752e+09  2.366455e+09  1.609955e+10
# total_tests   1.062798e+13  1.045365e+11  2.439071e+11  1.581341e+12
#
#                total_tests
# total_cases   1.062798e+13
# new_cases     1.045365e+11
# total_deaths  2.439071e+11
# new_tests     1.581341e+12
# total_tests   1.691126e+14

# %%
df1.corr()
# Out:
#               total_cases  new_cases  total_deaths  new_tests  total_tests
# total_cases      1.000000   0.953170      0.973786   0.916270     0.952602
# new_cases        0.953170   1.000000      0.947947   0.782498     0.730520
# total_deaths     0.973786   0.947947      1.000000   0.847980     0.845398
# new_tests        0.916270   0.782498      0.847980   1.000000     0.930440
# total_tests      0.952602   0.730520      0.845398   0.930440     1.000000

# %%
df1.var()
# Out:
# total_cases     5.545319e+12
# new_cases       6.458301e+08
# total_deaths    4.633920e+09
# new_tests       1.609955e+10
# total_tests     1.691126e+14
# dtype: float64

# %%
df1.std()
# Out:
# total_cases     2.354850e+06
# new_cases       2.541319e+04
# total_deaths    6.807290e+04
# new_tests       1.268840e+05
# total_tests     1.300433e+07
# dtype: float64

# %% [markdown]
# ***Proper visualization of dataset***

# %%
sns.distplot(df1['total_cases'])
sns.distplot(df1['new_cases']);

# %%
df1.plot(figsize = (10 , 10), linewidth = 5, fontsize = 20)

plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5, 0, 'Month')

# %%
df1.total_cases.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)

plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5, 0, 'Month')

# %%
sns.distplot(df1['total_tests'])
sns.distplot(df1['new_tests']);

# %%
df1.new_cases.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)

plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5, 0, 'Month')

# %%
df1.total_deaths.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)

plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5, 0, 'Month')

# %% [markdown]
# ***Trends and Seasonality in TimeSeries Dataset***

# %%
total_cases = df1[['total_cases']]
total_cases.rolling(12).mean().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);

# %%
new_cases = df1[['new_cases']]
new_cases.rolling(12).mean().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);

# %%
sns.pairplot(df1, size=2.5)
# Out:
# /home/vaibhav/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
with sns.axes_style('white'):
    sns.jointplot("new_cases", "total_cases", data=df1, kind='reg')

# %%
sns.distplot(df1['total_cases'], kde=False);
plt.axvline(0, color="k", linestyle="--");

# %%
sns.distplot(df1['new_cases'], kde=False);
plt.axvline(0, color="r", linestyle="--");

# %%
sns.distplot(df1['total_tests'], kde=False);
plt.axvline(0, color="r", linestyle="--");

# %%
sns.distplot(df1['new_tests'], kde=False);
plt.axvline(0, color="r", linestyle="--");

# %%
total_cases.diff().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month', fontsize = 20);

# %%
df1.total_cases.plot(figsize=(20,10),linewidth=5,fontsize=20)
plt.xlabel("Month",fontsize=20)
# Out:
# Text(0.5, 0, 'Month')

# %%
total_cases=df1[['total_cases']]
total_cases.rolling(12).mean().plot(figsize=(20,10),linewidth=5,fontsize=20)
plt.xlabel("Month",fontsize=20)
# Out:
# Text(0.5, 0, 'Month')
